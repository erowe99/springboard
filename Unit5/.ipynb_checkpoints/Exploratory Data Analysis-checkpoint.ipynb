# %% [markdown]
# # Unit 5: Data Storytelling
#
# Note: Assessment Page Views is about (6million, 13) and Jupyter notebook cannot handle most computations with it.
# This notebook will be an example using the first 10000 rows of the dataset. The actual graphs using this dataset will be created using
# iPython in the terminal and will be exported. The graphs will be stored in the same folder Unit5/figures.
#
# Link to full datasets on Google Drive: https://drive.google.com/drive/folders/15qYDNuxJRLteZ3MBbatIEnmn2N6bfvVM?usp=sharing
#
# ### EDA Section 1: Assessment Page Views
#
# Import relevant csv files derived from Assessment Page Views
#
# **Questions/Trends:**
#
# Average Duration on each Assignment -  see if there is a trend over the course of more assignments
#
# ### EDA Section 2: Course Grades
#
# Import relevant csv files derived from Course Grades/Grade export
#
# **Questions/Trends:**
#
# Distribution of Final Scores - overall and for the scores below 70
#
# Scatter plot of student grades and last login date - see if there is a correlation between the two
#
# Average final score by section
#
# Average final score by course
#
# Count of low scoring students by section
#
# Count of low scoring students by course
#
#
# ### EDA Section 3: Course Grades and Assessment Page Views
#
# Use relevant csv files from Section 1 and 2
#
# **Questions/Trends:**
#
# Final Score in the class by average assignment duration - see if there is a correlation

# %%
#Import libraries for data analysis and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pendulum
import datetime
from scipy import stats

# %%
"""
EDA Section 1: Assessment Page Views
"""
#Assessment Page Views
df = pd.read_csv('/Users/ethanrowe/Dev/springboard_data/KSU Assessment Page Views Fall 2018 Clean.csv', nrows = 10000, index_col = 0)
#Assessment Page Views columns: canvas_assignment_id, user_param_external_user_id, and Average Duration. Grouped by assignment id
df2 = pd.read_csv('/Users/ethanrowe/Dev/springboard_data/KSU Assignment Duration Average with User Id.csv', nrows = 10000)
#Assessment Page Views columns: user_param_external_user_id, canvas_assignment_id, and Average Duration. Grouped by user id
"""
df3 will be a rearrangement of df2 that will be easier to work with.
"""
#Assessment Page Views columns: canvas_assignment_id and Average Duration. Grouped by assignment id
df4 = pd.read_csv('/Users/ethanrowe/Dev/springboard_data/KSU Assessment Assignment Duration Averages.csv', nrows = 10000)
#Assessment Page Views columns: canvas_assignment_id, user_param_external_user_id, and Average Duration. 
#Grouped by assignment Id. Filtered to find user id entries with above average duration. (This need to be grouped by user id eventually)
df5 = pd.read_csv('/Users/ethanrowe/Dev/springboard_data/KSU Students with Above Average Assignment Duration.csv', nrows = 10000, index_col = 0)

# %%
df2.head()

cols = ['user_param_external_user_id', 'canvas_assignment_id', 'Average Duration']
df3 = df2[cols]
df3.head()
# Out:
#    user_param_external_user_id  canvas_assignment_id  Average Duration
# 0                        21650               22476.0       3453.500000
# 1                        33479               31317.0       5811.400000
# 2                        37111               40876.0      10265.000000
# 3                        37478               40876.0       3075.000000
# 4                        37993               40876.0       4410.333333

# %%
#Average Duration on each Assignment. reference: Unit5/figures/Average Duration on each Assignment.png
#Using a scatter plot to see if there is a trend over the course of more assignments
_ = plt.scatter(data = df4, x = 'canvas_assignment_id', y = 'Average Duration')
_ = plt.xlim(40000, 50000)
_ = plt.title('Average Duration on each Assignment')
_ = plt.xlabel('Assignment Id')
_ = plt.ylabel('Duration(ms)')
plt.show()

# %%
"""
EDA Section 2: Course Grades
"""
#Contains student grade info, shown below.
grades = pd.read_csv('/Users/ethanrowe/Dev/springboard_data/KSU Student Final Grades 2018 Anonymous.csv', index_col = 0)
#Contains student grade info for student that scored below 70; added column 'login time', shown below.
grades_below_70 = pd.read_csv('/Users/ethanrowe/Dev/springboard_data/grades_and_login_times(below 70 after oct).csv', index_col = 0)

# %%
grades
# Out:
#       student id  student sis  \
# 0          37888          NaN
# 1          37902          NaN
# 2          37956          NaN
# 3          38080          NaN
# 4          38176          NaN
# 5          38452          NaN
# 6          38684          NaN
# 7          38894          NaN
# 8          39189          NaN
# 9          39266          NaN
# 10         39269          NaN
# 11         39305          NaN
# 12         39327          NaN
# 13         39452          NaN
# 14         39574          NaN
# 15         39889          NaN
# 16         37094          NaN
# 17         37105          NaN
# 18         37117          NaN
# 19         37119          NaN
# 20         37122          NaN
# 21         37127          NaN
# 22         37129          NaN
# 23         37137          NaN
# 24         37141          NaN
# 25         37145          NaN
# 26         37149          NaN
# 27         37158          NaN
# 28         37160          NaN
# 29         37174          NaN
# ...          ...          ...
# 3126       38689          NaN
# 3127       38858          NaN
# 3128       38908          NaN
# 3129       39071          NaN
# 3130       38437          NaN
# 3131       38678          NaN
# 3132       38956          NaN
# 3133       39132          NaN
# 3134       39161          NaN
# 3135       37849          NaN
# 3136       39455          NaN
# 3137       39387          NaN
# 3138       38373          NaN
# 3139       39500          NaN
# 3140       39501          NaN
# 3141       39565          NaN
# 3142       39096          NaN
# 3143       39575          NaN
# 3144       26969          NaN
# 3145       39608          NaN
# 3146       35447          NaN
# 3147       39708          NaN
# 3148       39722          NaN
# 3149       39925          NaN
# 3150       39943          NaN
# 3151       40180          NaN
# 3152       36693          NaN
# 3153       41124          NaN
# 3154       41478          NaN
# 3155          45          NaN
#
#                                                  course  course id  \
# 0      WELL1000 Foundations for Healthy Living - Howton        622
# 1      WELL1000 Foundations for Healthy Living - Howton        622
# 2      WELL1000 Foundations for Healthy Living - Howton        622
# 3      WELL1000 Foundations for Healthy Living - Howton        622
# 4      WELL1000 Foundations for Healthy Living - Howton        622
# 5      WELL1000 Foundations for Healthy Living - Howton        622
# 6      WELL1000 Foundations for Healthy Living - Howton        622
# 7      WELL1000 Foundations for Healthy Living - Howton        622
# 8      WELL1000 Foundations for Healthy Living - Howton        622
# 9      WELL1000 Foundations for Healthy Living - Howton        622
# 10     WELL1000 Foundations for Healthy Living - Howton        622
# 11     WELL1000 Foundations for Healthy Living - Howton        622
# 12     WELL1000 Foundations for Healthy Living - Howton        622
# 13     WELL1000 Foundations for Healthy Living - Howton        622
# 14     WELL1000 Foundations for Healthy Living - Howton        622
# 15     WELL1000 Foundations for Healthy Living - Howton        622
# 16     WELL1000 Foundations for Healthy Living - Scheck        623
# 17     WELL1000 Foundations for Healthy Living - Scheck        623
# 18     WELL1000 Foundations for Healthy Living - Scheck        623
# 19     WELL1000 Foundations for Healthy Living - Scheck        623
# 20     WELL1000 Foundations for Healthy Living - Scheck        623
# 21     WELL1000 Foundations for Healthy Living - Scheck        623
# 22     WELL1000 Foundations for Healthy Living - Scheck        623
# 23     WELL1000 Foundations for Healthy Living - Scheck        623
# 24     WELL1000 Foundations for Healthy Living - Scheck        623
# 25     WELL1000 Foundations for Healthy Living - Scheck        623
# 26     WELL1000 Foundations for Healthy Living - Scheck        623
# 27     WELL1000 Foundations for Healthy Living - Scheck        623
# 28     WELL1000 Foundations for Healthy Living - Scheck        623
# 29     WELL1000 Foundations for Healthy Living - Scheck        623
# ...                                                 ...        ...
# 3126  WELL1000/01 Foundations for a Healthy Living -...        698
# 3127  WELL1000/01 Foundations for a Healthy Living -...        698
# 3128  WELL1000/01 Foundations for a Healthy Living -...        698
# 3129  WELL1000/01 Foundations for a Healthy Living -...        698
# 3130  WELL1000/01 Foundations for a Healthy Living -...        698
# 3131  WELL1000/01 Foundations for a Healthy Living -...        698
# 3132  WELL1000/01 Foundations for a Healthy Living -...        698
# 3133  WELL1000/01 Foundations for a Healthy Living -...        698
# 3134  WELL1000/01 Foundations for a Healthy Living -...        698
# 3135  WELL1000/01 Foundations for a Healthy Living -...        698
# 3136  WELL1000/01 Foundations for a Healthy Living -...        698
# 3137  WELL1000/01 Foundations for a Healthy Living -...        698
# 3138  WELL1000/01 Foundations for a Healthy Living -...        698
# 3139  WELL1000/01 Foundations for a Healthy Living -...        698
# 3140  WELL1000/01 Foundations for a Healthy Living -...        698
# 3141  WELL1000/01 Foundations for a Healthy Living -...        698
# 3142  WELL1000/01 Foundations for a Healthy Living -...        698
# 3143  WELL1000/01 Foundations for a Healthy Living -...        698
# 3144  WELL1000/01 Foundations for a Healthy Living -...        698
# 3145  WELL1000/01 Foundations for a Healthy Living -...        698
# 3146  WELL1000/01 Foundations for a Healthy Living -...        698
# 3147  WELL1000/01 Foundations for a Healthy Living -...        698
# 3148  WELL1000/01 Foundations for a Healthy Living -...        698
# 3149  WELL1000/01 Foundations for a Healthy Living -...        698
# 3150  WELL1000/01 Foundations for a Healthy Living -...        698
# 3151  WELL1000/01 Foundations for a Healthy Living -...        698
# 3152  WELL1000/01 Foundations for a Healthy Living -...        698
# 3153  WELL1000/01 Foundations for a Healthy Living -...        698
# 3154  WELL1000/01 Foundations for a Healthy Living -...        698
# 3155  WELL1000/01 Foundations for a Healthy Living -...        698
#
#       course sis       section  section id  section sis       term  term id  \
# 0            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 1            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 2            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 3            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 4            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 5            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 6            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 7            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 8            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 9            NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 10           NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 11           NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 12           NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 13           NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 14           NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 15           NaN  WELL 1000/01        1159          NaN  Fall 2018       20
# 16           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 17           NaN  WELL 1000/02        1160          NaN  Fall 2018       20
# 18           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 19           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 20           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 21           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 22           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 23           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 24           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 25           NaN  WELL 1000/02        1160          NaN  Fall 2018       20
# 26           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 27           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 28           NaN  WELL 1000/07        1164          NaN  Fall 2018       20
# 29           NaN  WELL 1000/02        1160          NaN  Fall 2018       20
# ...          ...           ...         ...          ...        ...      ...
# 3126         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3127         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3128         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3129         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3130         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3131         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3132         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3133         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3134         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3135         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3136         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3137         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3138         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3139         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3140         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3141         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3142         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3143         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3144         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3145         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3146         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3147         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3148         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3149         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3150         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3151         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3152         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3153         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3154         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
# 3155         NaN  WELL 1000/01        1384          NaN  Fall 2018       20
#
#       term sis  current score  final score enrollment state  \
# 0          NaN          87.42        86.29           active
# 1          NaN          94.90        93.67           active
# 2          NaN          94.31        93.09           active
# 3          NaN          97.18        95.92           active
# 4          NaN          84.40        83.30           active
# 5          NaN          93.08        93.08           active
# 6          NaN          94.66        93.44           active
# 7          NaN          94.93        93.70           active
# 8          NaN          91.24        90.06           active
# 9          NaN          54.56        54.49           active
# 10         NaN          92.84        91.64           active
# 11         NaN          88.76        87.61           active
# 12         NaN          74.02        73.06           active
# 13         NaN          85.49        84.39           active
# 14         NaN          92.49        91.30           active
# 15         NaN          78.62        77.60           active
# 16         NaN          88.46        88.46           active
# 17         NaN          92.22        92.22           active
# 18         NaN          64.48        64.48           active
# 19         NaN          93.87        93.87           active
# 20         NaN          82.20        82.20           active
# 21         NaN          96.95        96.95           active
# 22         NaN          95.59        95.59           active
# 23         NaN          84.35        84.35           active
# 24         NaN          89.65        89.65           active
# 25         NaN          87.61        87.61           active
# 26         NaN          83.44        83.44           active
# 27         NaN          94.60        94.60           active
# 28         NaN          95.38        95.38           active
# 29         NaN          54.51        54.51           active
# ...        ...            ...          ...              ...
# 3126       NaN          86.77        86.77           active
# 3127       NaN          98.18        98.18           active
# 3128       NaN          88.52        88.52           active
# 3129       NaN          63.32        63.32           active
# 3130       NaN          91.26        91.26           active
# 3131       NaN          86.67        86.67           active
# 3132       NaN          85.94        85.94           active
# 3133       NaN          86.53        86.53           active
# 3134       NaN          94.97        94.97           active
# 3135       NaN          94.88        94.88           active
# 3136       NaN         100.71       100.71           active
# 3137       NaN          39.92        39.92           active
# 3138       NaN          67.09        67.09           active
# 3139       NaN          42.59        42.59           active
# 3140       NaN          62.31        62.31           active
# 3141       NaN          91.84        91.84           active
# 3142       NaN          90.57        90.57           active
# 3143       NaN          90.43        90.43           active
# 3144       NaN          60.94        60.94           active
# 3145       NaN          79.24        79.24           active
# 3146       NaN          83.58        83.58           active
# 3147       NaN          90.85        90.85           active
# 3148       NaN          91.44        91.44           active
# 3149       NaN          60.59        60.59           active
# 3150       NaN          90.53        90.53           active
# 3151       NaN          85.44        85.44           active
# 3152       NaN          66.44        66.44           active
# 3153       NaN          91.93        91.93           active
# 3154       NaN          79.08        79.08           active
# 3155       NaN          11.72        11.72           active
#
#       unposted current score  unposted final score
# 0                      87.42                 86.29
# 1                      94.90                 93.67
# 2                      94.31                 93.09
# 3                      97.18                 95.92
# 4                      84.40                 83.30
# 5                      93.08                 93.08
# 6                      94.66                 93.44
# 7                      94.93                 93.70
# 8                      91.24                 90.06
# 9                      54.56                 54.49
# 10                     92.84                 91.64
# 11                     88.76                 87.61
# 12                     74.02                 73.06
# 13                     85.49                 84.39
# 14                     92.49                 91.30
# 15                     78.62                 77.60
# 16                     88.46                 88.46
# 17                     92.22                 92.22
# 18                     64.48                 64.48
# 19                     93.87                 93.87
# 20                     82.20                 82.20
# 21                     96.95                 96.95
# 22                     95.59                 95.59
# 23                     84.35                 84.35
# 24                     89.65                 89.65
# 25                     87.61                 87.61
# 26                     83.44                 83.44
# 27                     94.60                 94.60
# 28                     95.38                 95.38
# 29                     54.51                 54.51
# ...                      ...                   ...
# 3126                   86.77                 86.77
# 3127                   98.18                 98.18
# 3128                   88.52                 88.52
# 3129                   63.32                 63.32
# 3130                   91.26                 91.26
# 3131                   86.67                 86.67
# 3132                   85.94                 85.94
# 3133                   86.53                 86.53
# 3134                   94.97                 94.97
# 3135                   94.88                 94.88
# 3136                  100.71                100.71
# 3137                   39.92                 39.92
# 3138                   67.09                 67.09
# 3139                   42.59                 42.59
# 3140                   62.31                 62.31
# 3141                   91.84                 91.84
# 3142                   90.57                 90.57
# 3143                   90.43                 90.43
# 3144                   60.94                 60.94
# 3145                   79.24                 79.24
# 3146                   83.58                 83.58
# 3147                   90.85                 90.85
# 3148                   91.44                 91.44
# 3149                   60.59                 60.59
# 3150                   90.53                 90.53
# 3151                   85.44                 85.44
# 3152                   66.44                 66.44
# 3153                   91.93                 91.93
# 3154                   79.08                 79.08
# 3155                   11.72                 11.72
#
# [3156 rows x 16 columns]

# %%
grades_below70 = grades_below_70.sort_values('login time')
grades_below_70.head()
# Out:
#      course id  unposted final score           login time  student id  \
# 402        653                 12.09  2018-10-04 09:18:00       38758
# 403        635                  6.21  2018-10-05 01:31:00       37546
# 406        623                 27.92  2018-10-05 02:16:00        4103
# 407        674                 51.49  2018-10-05 03:58:00       35470
# 408        639                 23.95  2018-10-05 04:00:00       37181
#
#      student sis                                             course  \
# 402          NaN  WELL1000 Foundations for Healthy Living - Onli...
# 403          NaN  WELL1000 Foundations for Healthy Living - Onli...
# 406          NaN   WELL1000 Foundations for Healthy Living - Scheck
# 407          NaN   WELL1000 Foundations for Healthy Living - Bryant
# 408          NaN  WELL1000 Foundations for Healthy Living - Onli...
#
#      course sis        section  section id  section sis       term  term id  \
# 402         NaN  WELL 1000/W82        1217          NaN  Fall 2018       20
# 403         NaN   WELL1000/W67        1184          NaN  Fall 2018       20
# 406         NaN   WELL 1000/07        1164          NaN  Fall 2018       20
# 407         NaN   WELL 1000/46        1352          NaN  Fall 2018       20
# 408         NaN  WELL 1000/W72        1191          NaN  Fall 2018       20
#
#      term sis  current score  final score enrollment state  \
# 402       NaN          12.66        12.09           active
# 403       NaN           6.51         6.21           active
# 406       NaN          27.92        27.92           active
# 407       NaN          52.04        51.49           active
# 408       NaN          23.95        23.95           active
#
#      unposted current score
# 402                   12.66
# 403                    6.51
# 406                   27.92
# 407                   52.04
# 408                   23.95

# %%
#Distribution of Final Scores
_ = plt.hist(x =grades['unposted final score'], bins = 50)
_ = plt.title('Distribution of Final Scores')
_ = plt.xlabel('Score')
_ = plt.ylabel('Count')
_ = plt.savefig('figures/Distribution of Final Scores.png')
plt.show()

# %%
grades['unposted final score'].mean()
# Out:
# 79.59355513307999

# %%
#Distribution of low scoring students
#This data set has been cleaned for students who stopped participating. It removes the last spike seen in the above distribution.
_ = plt.hist(x =grades_below_70['unposted final score'], bins = 25)
_ = plt.title('Distribution of Scores below 70')
_ = plt.xlabel('Score')
_ = plt.ylabel('Count')
plt.show()

# %%
#Scatter plot of student grades and last login date
grades_below_70 = grades_below_70.sort_values('login time') 
time_series_df = grades_below_70.set_index('login time')
time_series_df = time_series_df.loc[:,'unposted final score']

#The dates are not evenly spaced out because the frequency of last logins is higher in December
xlabels = ['Oct 4', 'Nov 7', 'Nov 30', 'Dec 3', 'Dec 7', 'Dec 12']

_ = plt.axes(xticklabels = xlabels)
_ = plt.title('Final Scores (below 70) and last login date')
_ = plt.plot(time_series_df, linestyle = 'none', marker = '.')
_ = plt.xlabel('Login Date')
_ = plt.xticks(np.arange(0, 400, step=60), rotation=20)
_ = plt.ylabel('Score')
_ = plt.savefig('figures/Final Scores (below 70) and last login date.png')
plt.show()
time_series_df.head()
# Out:
# login time
# 2018-10-04 09:18:00    12.09
# 2018-10-05 01:31:00     6.21
# 2018-10-05 02:16:00    27.92
# 2018-10-05 03:58:00    51.49
# 2018-10-05 04:00:00    23.95
# Name: unposted final score, dtype: float64

# %%
#Average final score by section
section_avg_df = pd.DataFrame(grades.groupby(['section id'])['unposted final score'].mean())
print('\nAverage Score Grouped by Section ')
section_avg_df.columns = ['avg unposted final score']
print(section_avg_df.shape)

section_avg_df = section_avg_df.reset_index()
section_avg_df.head()
# Out:
# Average Score Grouped by Section
# (70, 1)
#    section id  avg unposted final score
# 0        1159                 86.415000
# 1        1160                 78.252045
# 2        1161                 78.416531
# 3        1164                 74.921489
# 4        1165                 83.806226

# %%
#Bar graph of average final score by section
_ = plt.bar(data = section_avg_df, x = 'section id', height = 'avg unposted final score')
_ = plt.title('Average Final Score by Section')
_ = plt.xlabel('Section Id')
_ = plt.ylabel('Average Final Score')
_ = plt.savefig('figures/Average Final Score by Section.png')
plt.show()

# %%
#Average score by course
course_avg_df = pd.DataFrame(grades.groupby(['course id'])['unposted final score'].mean())
print('\nAverage Score Grouped by Course ')
course_avg_df.columns = ['avg unposted final score']
print(course_avg_df.shape)

course_avg_df = course_avg_df.reset_index()
course_avg_df.head(100)
# Out:
# Average Score Grouped by Course
# (40, 1)
#     course id  avg unposted final score
# 0         622                 86.415000
# 1         623                 76.531868
# 2         624                 78.416531
# 3         626                 83.038286
# 4         627                 85.830972
# 5         628                 88.624694
# 6         629                 82.304100
# 7         631                 74.388952
# 8         632                 82.531020
# 9         633                 75.685686
# 10        634                 67.398246
# 11        635                 75.223548
# 12        636                 82.649167
# 13        637                 68.606735
# 14        638                 79.050900
# 15        639                 60.855714
# 16        640                 74.591235
# 17        641                 87.613542
# 18        642                 83.695700
# 19        643                 89.664433
# 20        644                 59.325686
# 21        645                 86.981042
# 22        646                 89.574400
# 23        647                 79.180690
# 24        648                 76.415493
# 25        649                 91.847273
# 26        650                 84.365000
# 27        651                 85.033600
# 28        652                 78.357391
# 29        653                 74.606327
# 30        654                 78.341304
# 31        655                 73.411800
# 32        656                 80.306250
# 33        657                 81.819432
# 34        658                 69.989314
# 35        659                 77.106168
# 36        673                 70.097692
# 37        674                 77.382292
# 38        696                 82.914118
# 39        698                 79.802368

# %%
#Bar graph of average final score by course
_ = plt.bar(data = course_avg_df, x = 'course id', height = 'avg unposted final score')
_ = plt.title('Average Final Score by Course Id')
_ = plt.xlabel('Course Id')
_ = plt.ylabel('Average Final Score')
_ = plt.savefig('figures/Average Final Score by Course Id.png')
plt.show()

# %%
#Count of low scoring students by section
grades_bad_section_df = pd.DataFrame(grades_below_70.groupby(['section id'])['unposted final score'].count())
grades_bad_section_df.columns = ['Count']
print('Shape')
print(grades_bad_section_df.shape)

grades_bad_section_df = grades_bad_section_df.reset_index()
print(grades_bad_section_df.head())

print('Section with most low scorers')
print(grades_bad_section_df[grades_bad_section_df['Count'] == grades_bad_section_df['Count'].max()])

_ = plt.bar(data = grades_bad_section_df, x = 'section id', height = 'Count')
_ = plt.title('Low Scoring Students(below 70) by Section')
_ = plt.xlabel('Section Id')
_ = plt.ylabel('Score')
_ = plt.savefig('figures/Low Scoring Students(below 70) by Section.png')
plt.show()
# Out:
# Shape
# (68, 1)
#    section id  Count
# 0        1159      1
# 1        1160      6
# 2        1161      7
# 3        1164      7
# 4        1165      4
# Section with most low scorers
#     section id  Count
# 59        1229     17

# %%
#Count of low scoring students by course
grades_bad_course_df = pd.DataFrame(grades_below_70.groupby(['course id'])['unposted final score'].count())
grades_bad_course_df.columns = ['Count']
print('Shape')
print(grades_bad_course_df.shape)
grades_bad_course_df = grades_bad_course_df.reset_index()
print(grades_bad_course_df.head())
print('Course with most low scorers')
print(grades_bad_course_df[grades_bad_course_df['Count'] == grades_bad_course_df['Count'].max()])
_ = plt.bar(data = grades_bad_course_df, x = 'course id', height = 'Count')
_ = plt.title('Low Scoring Students(below 70) by Course')
_ = plt.xlabel('Course Id')
_ = plt.ylabel('Score')
_ = plt.savefig('figures/Low Scoring Students(below 70) by Course')
plt.show()
# Out:
# Shape
# (40, 1)
#    course id  Count
# 0        622      1
# 1        623     13
# 2        624      7
# 3        626      6
# 4        627      4
# Course with most low scorers
#     course id  Count
# 34        658     26

# %%
"""
EDA Section 3: Course Grades and Assessment Page Views
"""
# Out:
# '\nEDA Section 3: Course Grades and Assessment Page Views\n'

# %%
#Question
#Prep the data frames for merging
#Not everything will match up here with partial code. The actual graph will be made in iPython using the full dataset.
student_duration_averages = pd.DataFrame(df3.groupby(['user_param_external_user_id'])['Average Duration'].mean())
student_duration_averages = student_duration_averages.reset_index()
student_duration_averages.columns = ['student id', 'average duration']
print(student_duration_averages.shape)
student_duration_averages.head()
# Out:
# (484, 2)
#    student id  average duration
# 0        1229      12304.000000
# 1        1669       5983.604369
# 2        1778       6253.875000
# 3        2641       6376.252979
# 4       12761       8504.857699

# %%
#Prep the dataframe for merging
student_final_grades = grades_below_70.loc[:, ['student id', 'unposted final score']]
print(student_final_grades.shape)
student_final_grades.head()
# Out:
# (326, 2)
#      student id  unposted final score
# 402       38758                 12.09
# 403       37546                  6.21
# 406        4103                 27.92
# 407       35470                 51.49
# 408       37181                 23.95

# %%
#Merge the dataframes.
student_duration_grades = pd.merge(student_duration_averages, student_final_grades, on = ['student id'], how = 'inner')

print(student_duration_grades.shape)
student_duration_grades.head()
# Out:
# (44, 3)
#    student id  average duration  unposted final score
# 0       16467       5670.932960                 69.41
# 1       18084       4993.342338                 53.73
# 2       22030       6756.300000                 49.60
# 3       31673       5083.498509                 45.74
# 4       32311       6302.706899                 55.47

# %%
#Scatter plot of student_duration_grades, reference: Final Score by Total Average Duration.png

_ = plt.title('Final Score by Total Average Assignment Duration')
_ = plt.scatter(data = student_duration_grades, x = 'average duration', y = 'unposted final score')
_ = plt.xlabel('Average Assignment Duration(ms)')
_ = plt.ylabel('Final Score')
plt.show()

# %% [markdown]
# # Conclusion
#
# Note: Any references made to graphs will be based off of the full dataset.
# If this is the case there will be a reference in the code cell and in the report below
#
# ### Section 1 Results: Assessment Page Views
#
# For this section, the only plot made was the scatter plot of Average Duration on each Assignment which can be found in Unit5/figures.
# I wanted to check if there was a trend in the amount of time spend on assignments to see if students eventually stopped participating as much.
#
# While the times did evenutally start to go down, it does not look like a strong or significant trend.
#
#
# ### Section 2 Results: Course Grades
#
# Looking at the distribution of final scores, the variance of the scores is very high, but it looks like most studets were passing the class.
#
# After isolating the students who actually finished the class in the Data Wranngling notebook, the distribution of scores below 70 was also anomoly free.
#
# The next scatter plot was the final score on the y-axis and the last login date for the student on the x-axis. I wanted to see if there was any clear correlation between the two since latest login date could be a measure of participation/engagement in the course.
# There is not a clear relationship between the two.
#
# Now, I want to check the duration for each assignment and compare that to the grade on the individual assignment. This will have to be calculated for each student individually and then plotted.
# I suspect that the relationship there, if there is a clear trend at all, will at least be more representative of student engagement.
#
#
#
# The bar graphs of average score by section and by course revealed no clear surprises either. The average scores did not seem to depend on those two factors.
# That was looking at the average score for the section though. When just counting how many students did poorly in a class, section id 1229 and course id 658 did stand out. This could be because the section/course was larger, so there was more room for low scoring student, or there was a problem with the instructor.
# The next step will be to add context to those numbers and look up what the course name, instructor, class size, and class structure is for those groups that did particularly poorly.
#
# ### Section 3 Results: Course Grades and Assessment Page Views
#
# The graph for this question is Unit5/figure/Final Score by Total Average Assignment Duration.png. This plot found the average duration across all assignments for each student. Then that was matched with the student's final grade in the course.
# The goal was to see if there was a trend between spending more time in the assignments and getting a better final score. Like I stated above, I also want to check average duration for an assignment with the actual grade on the assignment later on.
#
#
# There is also not a clear trend here either. It seems that students who spent significantly longer or shorter in total had worse grades. The x-axis is in milliseconds, so the spread is about 2 seconds to 15 seconds. Those who spend 2 seconds were probably guessing, and those that spend 15 seconds probably did not know the correct answer.
# The student who took a moderate amount of time had higher grades, but this **is not** an example of duration causing better grades.
#
#
#
# If the next unit on statistical analysis does not provide meaningful insights from these data sets, I will add an EDA section 4: Click Histories. There could be useful information in there, but it is not as clearly related to grades as Assessment Page Views is.
#
# The objective moving forward is still to identify factors that predict success and failure for students that take Perceivant's courses.
